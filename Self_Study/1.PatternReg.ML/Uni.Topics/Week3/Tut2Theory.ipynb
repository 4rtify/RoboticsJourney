# %% [markdown]
# # Tut2Theory.docx

# %% [markdown]
# 1.	What is a PRML model? Discuss how it is built and evaluated?
# - Classification models, regression and clustering models
# - Built off training data, evaluated against test data and scored
#
# 2.	Discuss data preparation in PRML projects. Why is it crucial? How do you ensure it is prepared well to ensure the modelling is able to tease it to build an accurate model?
# - Scaling data, so there's not outliers or skewed data.
# - Transform scale and logarithms
#
# 3.	When should you use classification over regression?
# - When determining labels or classes
#
# 4.	What is the difference between supervised, semi-supervised and unsupervised machine learning?
# - supervised means giving the X and y, (the input and desired output)
# - unsupervised means giving the X only, (only the input and the output is determined by the algorithm)
# - semi means only some of the data is labelled
#
# 5.	What’s the difference between a generative and discriminative model? Explain with examples.
# - Generative: Generates material based off learned data
# - Discriminative: Discriminates data into classes
#
# 6.	What Is a False Positive and False Negative and how are they Significant?
# - Is the prediction right or wrong / Is the prediction in positive context or negative context
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 7.	Define precision and recall. Why do we need to use these metrics?
# - We use Accuracy, Precision and recall to summarize the confusion matrix.
# - Accuracy is the number of correct predictions (TP and TN) divided by the number of all samples (all entries in the confusion matrix summed up)
#   - Accuracy = TP + TN / (TP + TN + FP + FN)
# - Precision / Recall / f-score - Other ways to summarise the confusion matrix.
#   - **Precision** measures how many of the samples predicted as positive are actually positive
#   - **Precision** is used as a performance metric when the goal is to limit the FP
#   - **Precision** is known as the Positive Prediction Value (PPV)
#   - **Precision** = TP / TP + FP
#   - **Recall** measures how many of the positive samples are captured by the positive predictions
#   - **Recall** = TP / TP + FN
#   - **Recall** is used as a performance metric when we need to identify all positive samples.
#   - **Recall** is used when it's important to avoid false negatives.
#
# ### ToDo Chap 5 - Model Evaluation and Improvement
#
# 8.	What is the F1 score? How would you use it?
# 9.	Explain the Confusion Matrix and Correlation Matrix and explain how they are used in model development.
# 10.	Explain what a classification report is and interpret the following example of a classification report.
#
# 11.	Explain the R2 (coefficient of determination measure).  When should it be used? How is it different to regression coefficient?
# 12. Regression / mean square error - 0 would be on point - is this error tolerable?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data
# - Qualitative: The quality, eg "It was good"
# - Quantitative: The amount, eg "It was 5"
